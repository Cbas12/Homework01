# %%
# Filter the dataframe for the specified date range
filtered_df = df_trips[(df_trips['lpep_pickup_datetime'] >= '2019-10-01 00:00:00') & 
                       (df_trips['lpep_pickup_datetime'] < '2019-11-01 00:00:00')]

# Create a new column 'distancias' based on the conditions
filtered_df['distancias'] = pd.cut(filtered_df['trip_distance'],
                                   bins=[-float('inf'), 1, 3, 7, 10, float('inf')],
                                   labels=['0-1', '1-3', '3-7', '7-10', '10+'],
                                   right=True)

print(filtered_df['distancias'].value_counts().sort_index())
# Out:
#         trip_distance distancias
# 0                5.88        3-7
# 1                0.80        0-1
# 2                7.50       7-10
# 3                0.90        0-1
# 4                2.52        1-3
# ...               ...        ...
# 476381           7.04       7-10
# 476382           0.00        0-1
# 476383           3.90        3-7
# 476384           3.08        3-7
# 476385           6.84        3-7
#
# [476354 rows x 2 columns]
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14484\1877831504.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['distancias'] = pd.cut(filtered_df['trip_distance'],

# %%
print(filtered_df['distancias'].value_counts().sort_index())
# Out:
# 0-1     104830
# 1-3     198995
# 3-7     109642
# 7-10     27686
# 10+      35201
# Name: distancias, dtype: int64

# %%
import pandas as pd
from sqlalchemy import create_engine, text
import pandasql as psql

# %%
#read trips
url_trips = "https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-10.csv.gz"

df_trips = pd.read_csv(url_trips, compression='gzip',dtype={3: 'object'})
df_trips
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-10-01 00:26:02   2019-10-01 00:39:58
# 1            1.0  2019-10-01 00:18:11   2019-10-01 00:22:38
# 2            1.0  2019-10-01 00:09:31   2019-10-01 00:24:47
# 3            1.0  2019-10-01 00:37:40   2019-10-01 00:41:49
# 4            2.0  2019-10-01 00:08:13   2019-10-01 00:17:56
# ...          ...                  ...                   ...
# 476381       NaN  2019-10-31 23:30:00   2019-11-01 00:00:00
# 476382       NaN  2019-10-31 23:03:00   2019-10-31 23:24:00
# 476383       NaN  2019-10-31 23:02:00   2019-10-31 23:23:00
# 476384       NaN  2019-10-31 23:42:00   2019-10-31 23:56:00
# 476385       NaN  2019-10-31 23:23:00   2019-10-31 23:56:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0           112           196
# 1                       N         1.0            43           263
# ...

# %%
#read zones
url_zones = "https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv"

df_zones = pd.read_csv(url_zones)
df_zones
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
engine.connect()

# %%
engine.connect()

# %%
df_trips.dtypes
# Out:
# VendorID                   int64
# lpep_pickup_datetime      object
# lpep_dropoff_datetime     object
# store_and_fwd_flag        object
# RatecodeID                 int64
# PULocationID               int64
# DOLocationID               int64
# passenger_count            int64
# trip_distance            float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# ehail_fee                float64
# improvement_surcharge    float64
# total_amount             float64
# payment_type               int64
# trip_type                float64
# congestion_surcharge     float64
# dtype: object

# %%
df_trips.lpep_pickup_datetime = pd.to_datetime(df_trips.lpep_pickup_datetime)
df_trips.lpep_dropoff_datetime = pd.to_datetime(df_trips.lpep_dropoff_datetime)

# %%
df_trips
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-10-01 00:26:02   2019-10-01 00:39:58
# 1            1.0  2019-10-01 00:18:11   2019-10-01 00:22:38
# 2            1.0  2019-10-01 00:09:31   2019-10-01 00:24:47
# 3            1.0  2019-10-01 00:37:40   2019-10-01 00:41:49
# 4            2.0  2019-10-01 00:08:13   2019-10-01 00:17:56
# ...          ...                  ...                   ...
# 476381       NaN  2019-10-31 23:30:00   2019-11-01 00:00:00
# 476382       NaN  2019-10-31 23:03:00   2019-10-31 23:24:00
# 476383       NaN  2019-10-31 23:02:00   2019-10-31 23:23:00
# 476384       NaN  2019-10-31 23:42:00   2019-10-31 23:56:00
# 476385       NaN  2019-10-31 23:23:00   2019-10-31 23:56:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0           112           196
# 1                       N         1.0            43           263
# ...

# %%
print(pd.io.sql.get_schema(df_trips,name='yellow_taxi_data',con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" FLOAT(53),
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" FLOAT(53),
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type FLOAT(53),
# 	trip_type FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_trips_iter = pd.read_csv(url_trips, compression='gzip',dtype={3: 'object'},iterator=True,chunksize=100000)

# %%
df_trips = next(df_trips_iter)

# %%
df_trips.head(n=0).to_sql(name='yellow_taxi_data',con=engine,if_exists='replace')
# Out:
# 0

# %%
df_zones.to_sql(name='zones',con=engine,if_exists='replace')
# Out:
# 265

# %%
df_trips.to_sql(name='yellow_taxi_data',con=engine,if_exists='append')

# %%
while True:
    df_trips = next(df_trips_iter)
    df_trips.lpep_pickup_datetime = pd.to_datetime(df_trips.lpep_pickup_datetime)
    df_trips.lpep_dropoff_datetime = pd.to_datetime(df_trips.lpep_dropoff_datetime)
    df_trips.to_sql(name='yellow_taxi_data',con=engine,if_exists='append')
    print('otra inserción...')
# Out:
# otra inserción...
# otra inserción...
# otra inserción...
# otra inserción...
# otra inserción...
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[40], line 2
#       1 while True:
# ----> 2     df_trips = next(df_trips_iter)
#       3     df_trips.lpep_pickup_datetime = pd.to_datetime(df_trips.lpep_pickup_datetime)
#       4     df_trips.lpep_dropoff_datetime = pd.to_datetime(df_trips.lpep_dropoff_datetime)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1698, in TextFileReader.__next__(self)
#    1696 def __next__(self) -> DataFrame:
#    1697     try:
# -> 1698         return self.get_chunk()
#    1699     except StopIteration:
#    1700         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1810, in TextFileReader.get_chunk(self, size)
# ...

# %%
df_trips['tip_amount'].sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14484\3056030910.py in ?()
# ----> 1 df_trips['tip_amount'].sort()
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'sort'
